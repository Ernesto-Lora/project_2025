# %%
import numpy as np
import pandas as pd
from pgmpy.readwrite import XMLBIFReader
import random
import copy

# Settings
from discriminativeBN import DiscriminativeBN
from simplexMethod import NelderMeadOptimizer
from hookeJeeves import HookeJeevesOptimizer
from lbfgs import LBFGSOptimizerWrapper

# %%
import time
from get_params_lbfgs import get_params_l

start_time = time.time()

get_params_l(
    xml_file="models/australianTAN.xml",
    csv_file="datasets/AustralianDisc.csv",
    target_var="A15",
    Optimizer_fun=LBFGSOptimizerWrapper,
    max_iter=20,
    params_file_name="final_tablesAustralianTAN_LBFGS.pkl",
    betas_file_name="final_betasAustralianTAN_LBFGS.pkl"
)

end_time = time.time()

elapsed_minutes = (end_time - start_time) / 60
print(f"Elapsed time: {elapsed_minutes:.2f} minutes")
# Out:
# Starting Optimization with 118 parameters...
# --- Starting L-BFGS Optimization (Dim: 118) ---
# Initial Best Score: -492.1031 (CLL)
# ------------------------------
# ------------------------------
# Optimization Finished. Reason: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Total Iterations: 20
# Final Best Score: -197.0797 (CLL)
#
# Optimization Complete.
# Final Conditional Log Likelihood: -197.0797
#
# Learned Table for A15:
# [[0.40107784 0.59892216]]
# Elapsed time: 0.07 minutes

# %%
import pickle

with open("final_tablesAustralianTAN_LBFGS.pkl", "rb") as f:
    tablesAusTAN = pickle.load(f)

from get_accuracy import get_accuracy
bnAusTAn = DiscriminativeBN(xml_path="models/australianTAN.xml", target_col = "A15")
df_Aus = pd.read_csv("datasets/AustralianDisc.csv")
get_accuracy(bn= bnAusTAn, final_tables= tablesAusTAN, df = df_Aus)
# Out:
# --- Starting Evaluation ---
# Accuracy: 89.71%
#
# Confusion Matrix:
# [[346  37]
#  [ 34 273]]
#
# Row 0 Actual: A
# Row 0 Pred  : A
